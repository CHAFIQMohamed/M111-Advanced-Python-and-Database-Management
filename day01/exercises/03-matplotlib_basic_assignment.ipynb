# %% [markdown]
# # Matplotlib exercices

# %% [markdown]
# In this exercise, we are using Pandas and Matplotlib to visualize Company Sales Data. The data is located under the folder `../data/company_sales_data.csv`.
#
# ![company_sales_data](../data/company_sales_data.webp)

# %%
import pandas as pd
data = pd.read_csv("../data/company_sales_data.csv")

# %%
data
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %% [markdown]
# ## Exercise 1
# **Read Total profit of all months and show it using a line plot**
#
# Total profit data provided for each month. Generated line plot must include the following properties:
# - X label name = Month Number
# - Y label name = Total profit
# The line plot graph should look like this.
#
# **Expected output**
#
# <img src="../data/Company_profit_per_month.png" alt="Company_profit_per_month" style="width: 500px;"/>

# %%
from matplotlib import pyplot as plt



plt.figure()
plt.plot(data["month_number"],data["total_profit"] )
plt.xlabel("Month")
plt.ylabel("Total profit")
plt.title("company profit per month")
plt.legend(loc="upper left")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Exercise 2
# **Get total profit of all months and show line plot with the following Style properties**
# - Line Style dotted and Line-color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# **Expected output**
#
# <img src="../data/company_sales_data_of_last_year.png" alt="company_sales_data_of_last_year" style="width: 700px;"/>

# %%
# write your code here
from matplotlib import pyplot as plt

plt.figure(figsize=(10, 6), dpi=80)
plt.plot(data["month_number"],data["total_profit"],linestyle='dashed',color="red",marker = 'o',mfc = 'k' )
plt.xlabel("Month number")
plt.ylabel("profit in dollar")
plt.title("company sales data of last year")
plt.legend(['profit data of last year'], loc='lower right')

plt.show()

# %% [markdown]
# ## Exercise 3
# **Read all product sales data and show it  using a multiline plot**
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).
# **Expected output**
#
# <img src="../data/sales_data.png" alt="sales_data" style="width: 500px;"/>

# %%
# write your code here
# write your code here
from matplotlib import pyplot as plt

plt.figure(figsize=(10, 5), dpi=80)
date=data["month_number"]
plt.plot(date,data["facecream"],color="red" ,label='face cream sales data',marker = 'o')



plt.plot(date,data["toothpaste"],color="green",label='toothpaste sales data',marker = 'o' )

plt.plot(date,data["bathingsoap"],color="black",label='bathingsoap sales data',marker = 'o' )

plt.plot(date,data["shampoo"],color="yellow" ,label='shampoo sales data',marker = 'o')

plt.plot(date,data["moisturizer"],color="blue" ,label='moisturizer sales data',marker = 'o')
plt.legend()
plt.xlabel("Month number")
plt.ylabel("profit in dollar")
plt.title("salles units in number")


plt.show()

# %% [markdown]
# ## Exercise 4
# **Read toothpaste sales data of each month and show it using a scatter plot**
# Also, add a grid in the plot. gridline style should “–“.
#
# **Expected output**
#
# <img src="../data/Tooth_paste_Sales_data.png" alt="sales_data" style="width: 700px;"/>

# %%
# write your code here
plt.figure(figsize=(9, 4), dpi=80)
plt.scatter(date, data["toothpaste"],label="tooth paste sales data")
plt.xlabel("Month number")
plt.ylabel("profit in dollar")
plt.title("number of unites sold")
plt.grid(linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# ## Exercise 5
# **Read face cream and facewash product sales data and show it using the bar chart**
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# **Expected output**
#
# <img src="../data/Facewash_and_facecream_sales_data.png" alt="sales_data" style="width: 700px;"/>

# %%
# write your code here

month=data["month_number"]
plt.figure(figsize=(10, 4), dpi=80)
plt.bar(month-0.2, data['facecream'],color ='r', width=0.2,
        edgecolor ='grey', label ='face cream sales data',align='center')
plt.bar(month, data['facewash'], width=0.2,label ='face wash sales data',align='center')
plt.xlabel("Month number")
plt.ylabel("profit in dollar")
plt.title("number of unites sold")
plt.grid(linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# ## Exercise 6
# **Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk**
#
# **Expected output**
#
# <img src="../data/sales_data_of_bathingsoap.png" alt="sales_data_of_bathingsoap" style="width: 700px;"/>

# %%
# write your code here
# write your code here

month=data["month_number"]
plt.figure(figsize=(10, 4), dpi=80)
plt.bar(month-0.2, data['bathingsoap'],color ='b', width=0.5,
        edgecolor ='grey',align='center')

plt.xlabel("Month number")
plt.ylabel("profit in dollar")
plt.title("bathingsoap sales data")
plt.grid(linestyle='--')
plt.savefig('my_plot.png')
plt.show()

# %% [markdown]
# ## Exercise 7
# **Read the total profit of each month and show it using the histogram to see the most common profit ranges**
#
# **Expected output**
#
# <img src="../data/Profit_data.png" alt="Profit_data" style="width: 700px;"/>

# %%
# write your code here
plt.figure(figsize=(10, 4), dpi=80)
plt.hist(data['total_profit'],bins = [150000, 175000, 200000, 225000, 250000,300000,350000])
plt.xlabel("profit range in dollar")
plt.ylabel("Actual profit in dollae")
plt.title("profit data")

plt.legend(['profit data'])
plt.show()

# %% [markdown]
# ## Exercise 8
# **Calculate total sale data for last year for each product and show it using a Pie chart**
#
# *Note: In Pie chart display Number of units sold per year for each product in percentage.*
#
# **Expected output**
#
# <img src="../data/sales_data_pi_chart.png" alt="sales_data_pi_chart" style="width: 700px;"/>

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
# write your code here
plt.figure(figsize=(10, 8))
mylabels = ["facecream", "facewash", "toothpaste", "bathingsoap","shampoo","moisturizer"]
Y=[data['facecream'].sum(), data['facewash'].sum(),data['toothpaste'].sum(),data['bathingsoap'].sum(),
data['shampoo'].sum(),data['moisturizer'].sum()]
plt.pie(Y,labels=mylabels)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Exercise 9
# **Read Bathing soap facewash of all months and display it using the Subplot**
#
# **Expected output**
#
# <img src="../data/Sales_data_of_a_facewash.png" alt="Sales_data_of_a_facewash" style="width: 700px;"/>

# %%
# write your code here
plt.figure(figsize=(10, 5), dpi=80)

plt.subplot(2, 1, 1)
plt.plot(month,data["bathingsoap"],color="black" ,marker = 'o')
plt.title("sales data for bathingsoap")


#plot 2:


plt.subplot(2, 1, 2)
plt.plot(month,data['facewash'],color="red" ,marker = 'o')
plt.title("sales data for facewash")
plt.xlabel("Month number")
plt.ylabel("sales unites in number")

plt.show()

# %% [markdown]
# ## Exercise 10
# **Read all product sales data and show it using the stack plot**
#
# **Expected output**
#
# <img src="../data/product_sales_stack_plot.png" alt="product_sales_stack_plot" style="width: 700px;"/>

# %%
# write your code here
plt.figure(figsize=(10, 6), dpi=80)
date=data["month_number"]
plt.plot([],[],color="red" ,label='face cream sales data',marker = 'o')

plt.plot([],[],color="orange" ,label='face cream sales data',marker = 'o')

plt.plot([],[],color="green",label='toothpaste sales data',marker = 'o' )

plt.plot([],[],color="black",label='bathingsoap sales data',marker = 'o' )

plt.plot([],[],color="yellow" ,label='shampoo sales data',marker = 'o')

plt.plot([],[],color="blue" ,label='moisturizer sales data',marker = 'o')
plt.stackplot(month,data["facecream"],data["facewash"], data["toothpaste"], data["bathingsoap"],
              data["shampoo"],data["moisturizer"], baseline ='zero',
              colors =['red', 'orange',
                       'green','black','yellow','blue'])
plt.legend(loc='upper left')
plt.xlabel("Month number")
plt.ylabel("salles units in number")
plt.title("All product sales data using stack plot")


plt.show()
